# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris') 
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
avg_petal = df.groupby("species")["petal_length"].mean()
plt.figure(figsize=(7,5))

plt.fill_between(avg.index, avg.values, alpha=0.6, label=avg.index)

plt.title("Average Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Average Petal Length (cm)")

plt.grid(True, which="both")

plt.legend(avg_petal.index, title="Species", fontsize=12, loc="lower right")

plt.tight_layout()
plt.savefig("area_chart.png")   # saves image
plt.show()

# %%
plt.figure(figsize=(10, 8)) 

x = df["sepal_length"]
y = df["sepal_width"]
sizes = df["petal_length"]

color_map = {
    'setosa': 'red',
    'versicolor': 'green',
    'virginica': 'blue'
}

colors = df["species"].map(color_map)

plt.scatter(x, y, s=sizes*30, alpha=0.6, c=colors,label=species)
plt.xlabel("sepal_length")
plt.ylabel("sepal_width")
plt.legend()

plt.title("Bubble Chart")
plt.show()

# %%
iris_numeric = df[["sepal_length", "sepal_width", "petal_length", "petal_width"]]
cor_mat = iris_numeric.corr()

sns.heatmap(cor_mat, annot=True)
plt.title("Heatmap of Iris features")
plt.show()

# %%
sns.boxplot(x="species",y="petal_length",data=df,palette=["red", "green", "blue"])

plt.title("Petal Length Distribution by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length")

plt.show()
# Out:
# C:\Users\MAN GHADIYA\AppData\Local\Temp\ipykernel_22644\2710117537.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="species",y="petal_length",data=df,palette=["red", "green", "blue"])

# %% [markdown]
# #

# %%
sns.violinplot(
x="species", y="petal_width",data=df)
plt.title("Petal Width Distribution by Species")
plt.show()

# %%
sns.pairplot(data=df, hue="species")
plt.suptitle("Iris Species Pair Plot")
plt.show()
